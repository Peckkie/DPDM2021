# %% [markdown]
# <a href="https://colab.research.google.com/github/Peckkie/DPDM2021/blob/main/Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Yupaporn Wanna
# ## Yupaporn Wanna
# ### Yupaporn Wanna
#
# text in this cell are markdown
#
# ![image.png](data:image/png;base64,...)

# %%
#coding cell
print('Yupaporn Wanna')
# Out:
# Yupaporn Wanna
